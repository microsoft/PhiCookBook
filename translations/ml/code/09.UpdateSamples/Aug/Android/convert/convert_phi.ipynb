# %%
TFLITE_MODEL = 'Your Phi-3.5 tflite model path'
TOKENIZER_MODEL = 'Your Phi-3.5 tokenizer.model path'
START_TOKEN = "<s>"
STOP_TOKENS = ["<|endoftext|>"]
OUTPUT_FILENAME = "Your Phi-3.5 task model path"
ENABLE_BYTES_TO_UNICODE_MAPPING = True

# %%
import mediapipe as mp
from mediapipe.tasks.python.genai import bundler

# %%
config = bundler.BundleConfig(
    tflite_model=TFLITE_MODEL,
    tokenizer_model=TOKENIZER_MODEL,
    start_token=START_TOKEN,
    stop_tokens=STOP_TOKENS,
    output_filename=OUTPUT_FILENAME,
    enable_bytes_to_unicode_mapping=ENABLE_BYTES_TO_UNICODE_MAPPING,
)

# %%
bundler.create_bundle(config)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# അസ്വീകരണ കുറിപ്പ്:
# ഈ രേഖ AI വിവർത്തന സേവനമായ [Co-op Translator](https://github.com/Azure/co-op-translator) ഉപയോഗിച്ച് വിവർത്തനം ചെയ്തതാണ്. ഞങ്ങൾ കൃത്യതയ്ക്ക് ശ്രമിക്കുന്നതായിരുന്നുവെങ്കിലും, യാന്ത്രിക വിവർത്തനങ്ങളിൽ പിശകുകളും അകൃത്യതകളും ഉണ്ടാകാൻ സാധ്യതയുണ്ടെന്ന് ദയവായി ഗൗരവത്തോടെ ശ്രദ്ധിക്കുക. നിർണായക വിവരങ്ങൾക്ക്, മാതൃഭാഷയിലെ യഥാർത്ഥ രേഖയാണ് അധികാരപ്രദമായ ഉറവിടം എന്നാണ് പരിഗണിക്കേണ്ടത്; അതിനാൽ പ്രൊഫഷണൽ മനുഷ്യവിവർത്തനം അനിവാര്യമായിരിക്കാം. ഈ വിവർത്തനത്തിന്റെ ഉപയോഗത്തിൻറെഫലമായി ഉണ്ടായേക്കാവുന്ന ഏതെങ്കിലും തെറ്റിദ്ധാരണങ്ങൾക്കും തെറ്റായ വ്യാഖ്യാനങ്ങൾക്കും ഞങ്ങൾ ഉത്തരവാദികളല്ല.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
